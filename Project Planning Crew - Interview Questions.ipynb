# %% [markdown]
# <div class='status' style='background-color: #0c4a6e; color: white; padding-top: 4px; padding-bottom: 4px; padding-left: 20px; padding-right: 20px; border-radius: 10px; font-family: Arial, sans-serif; font-size: 26px; display: inline-block; text-align: center; box-shadow: 0px 3px 4px rgba(0, 0, 0, 0.5);'><b>Crewai</B> - Project Planning - <b>Notion Integration Project</b></div>
#
# 1. **Notion Integration Project** - Build Tools to interact with Notion API and assess a database and all the pages within a database and then write a report.
# 3. Use the **Project Planning Crew** to extimate the work involved. Utilise the agnets.yaml and tools.yaml form deeplearning.ai lessons.

# %% [markdown]
# <div class='status' style='background-color: #f59e0b; color: white; padding-top: 2px; padding-bottom: 2px; padding-left: 7px; padding-right: 7px; border-radius: 6px; font-family: Arial, sans-serif; font-size: 18px; display: inline-block; text-align: center; box-shadow: 0px 3px 4px rgba(0, 0, 0, 0.2);'><b>Loading</b> Libraries</div>

# %%
# Warning control
import warnings
warnings.filterwarnings('ignore')

# Load environment variables
from helper import load_env
load_env()

import os
import yaml
from crewai import Agent, Task, Crew

# %%
os.environ['OPENAI_MODEL_NAME'] = 'gpt-4o-mini'

# %% [markdown]
# <div class='status' style='background-color: #0e7490; color: white; padding-top: 2px; padding-bottom: 2px; padding-left: 7px; padding-right: 7px; border-radius: 6px; font-family: Arial, sans-serif; font-size: 18px; display: inline-block; text-align: center; box-shadow: 0px 3px 4px rgba(0, 0, 0, 0.2);'>Loading <b>Agents + Tasks</b> form YAML file</div>

# %%
# Define file paths for YAML configurations
files = {
    'agents': 'config/agents.yaml',
    'tasks': 'config/tasks.yaml'
}

# Load configurations from YAML files
configs = {}
for config_type, file_path in files.items():
    with open(file_path, 'r') as file:
        configs[config_type] = yaml.safe_load(file)

# Assign loaded configurations to specific variables
agents_config = configs['agents']
tasks_config = configs['tasks']

# %% [markdown]
# ### Create Pydantic Models for Structured Output

# %%
from typing import List
from pydantic import BaseModel, Field

class TaskEstimate(BaseModel):
    task_name: str = Field(..., description="Name of the task")
    estimated_time_hours: float = Field(..., description="Estimated time to complete the task in hours")
    required_resources: List[str] = Field(..., description="List of resources required to complete the task")

class Milestone(BaseModel):
    milestone_name: str = Field(..., description="Name of the milestone")
    tasks: List[str] = Field(..., description="List of task IDs associated with this milestone")

class ProjectPlan(BaseModel):
    tasks: List[TaskEstimate] = Field(..., description="List of tasks with their estimates")
    milestones: List[Milestone] = Field(..., description="List of project milestones")

# %% [markdown]
# ### Create Crew, Agents and Tasks

# %%
# Creating Agents
project_planning_agent = Agent(
  config=agents_config['project_planning_agent']
)

estimation_agent = Agent(
  config=agents_config['estimation_agent']
)

resource_allocation_agent = Agent(
  config=agents_config['resource_allocation_agent']
)

# Creating Tasks
task_breakdown = Task(
  config=tasks_config['task_breakdown'],
  agent=project_planning_agent
)

time_resource_estimation = Task(
  config=tasks_config['time_resource_estimation'],
  agent=estimation_agent
)

resource_allocation = Task(
  config=tasks_config['resource_allocation'],
  agent=resource_allocation_agent,
  output_pydantic=ProjectPlan # This is the structured output we want
)

# Creating Crew
crew = Crew(
  agents=[
    project_planning_agent,
    estimation_agent,
    resource_allocation_agent
  ],
  tasks=[
    task_breakdown,
    time_resource_estimation,
    resource_allocation
  ],
  verbose=True
)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In [5], line 3
#       1 # Creating Agents
#       2 project_planning_agent = Agent(
# ----> 3   config=agents_config['project_planning_agent']
#       4 )
#       6 estimation_agent = Agent(
#       7   config=agents_config['estimation_agent']
#       8 )
#      10 resource_allocation_agent = Agent(
#      11   config=agents_config['resource_allocation_agent']
#      12 )
#
# KeyError: 'project_planning_agent'

# %% [markdown]
# ### Crew's Input

# %%
project = 'Preperation for Interview as Practice Manager for a GP surgery UK'
industry = 'Healthcare'
project_objectives = 'Be interview ready by Dec 6 the date today is Nov 19'
team_members = """
- Jan du Plessis (Practice Manager)
"""
project_requirements = """
- Practice Interview questions
- Prepare a presentaion Innovative Primary Care - how I see innovation in primary care 
- Have time to practice my interview questions and improve delivery
"""

# %% [markdown]
# <div class='status' style='background-color: #be123c; color: white; padding-top: 2px; padding-bottom: 2px; padding-left: 7px; padding-right: 7px; border-radius: 6px; font-family: Arial, sans-serif; font-size: 18px; display: inline-block; text-align: center; box-shadow: 0px 3px 4px rgba(0, 0, 0, 0.2);'><b>Kickoff</b> the Crew</div>

# %%
# The given Python dictionary
inputs = {
  'project_type': project,
  'project_objectives': project_objectives,
  'industry': industry,
  'team_members': team_members,
  'project_requirements': project_requirements
}

# Run the crew
result = crew.kickoff(
  inputs=inputs
)
# Out:
# # Agent: The Ultimate Project Planner
# ## Task: Carefully analyze the project_requirements for the Preperation for Interview as Practice Manager for a GP surgery UK project and break them down into individual tasks. Define each task's scope in detail, set achievable timelines, and ensure that all dependencies are accounted for:
#
# - Practice Interview questions
# - Prepare a presentaion Innovative Primary Care - how I see innovation in primary care
# - Have time to practice my interview questions and improve delivery
#
#
# Team members:
#
# - Jan du Plessis (Practice Manager)
#
#
#
#
# # Agent: The Ultimate Project Planner
# ## Final Answer:
# Below is the comprehensive breakdown for the project "Preparation for Interview as Practice Manager for a GP surgery UK." This includes detailed tasks, specific timelines aligned with the deadline of December 6, and all dependencies accounted for.
#
# ### Task Breakdown with Detailed Descriptions
#
# 1. **Research Common Practice Manager Interview Questions**
#    - **Scope**: Identify and compile key interview questions typically asked for Practice Manager roles in GP surgeries.
#    - **Timeline**: Nov 19 – Nov 21 (3 days).
#    - **Dependencies**: None.
#    - **Deliverables**: List of at least 15 common interview questions.
#
# 2. **Prepare Responses for Interview Questions**
#    - **Scope**: Craft personalized responses for each identified question using the STAR (Situation, Task, Action, Result) technique to illustrate experience and competencies effectively.
#    - **Timeline**: Nov 22 – Nov 25 (4 days).
#    - **Dependencies**: Completion of Task 1.
#    - **Deliverables**: Document containing rehearsed answers to all identified questions.
#
# 3. **Develop Presentation on Innovative Primary Care**
#    - **Scope**: Create a presentation covering ideas on how to enhance innovation within primary care, focusing on technology integration, patient care models, and community engagement.
#    - **Timeline**: Nov 26 – Nov 28 (3 days).
#    - **Dependencies**: None.
#    - **Deliverables**: Completed PowerPoint presentation maximum of 10 slides.
#
# 4. **Rehearse Presentation Delivery**
#    - **Scope**: Practice the delivery of the presentation multiple times, focusing on pacing, clarity, and engagement techniques.
#    - **Timeline**: Nov 29 – Dec 1 (3 days).
#    - **Dependencies**: Completion of Task 3.
#    - **Deliverables**: Recorded practice sessions for self-review.
#
# 5. **Mock Interview with Feedback**
#    - **Scope**: Schedule a mock interview session with Jan du Plessis or another mentor to simulate the interview experience and get constructive feedback.
#    - **Timeline**: Dec 2 (1 day).
#    - **Dependencies**: Completion of Task 2.
#    - **Deliverables**: Feedback notes and suggestions for improvement.
#
# 6. **Finalize Interview Preparation**
#    - **Scope**: Review all materials (responses and presentation), make necessary adjustments based on the mock interview feedback, and prepare materials for the actual interview (printouts, notes, etc.).
#    - **Timeline**: Dec 3 – Dec 5 (3 days).
#    - **Dependencies**: Completion of Task 4 and Task 5.
#    - **Deliverables**: Finalized interview documents and presentation materials, all organized.
#
# 7. **Day Before Interview Preparation**
#    - **Scope**: Light review of materials, prepare outfit, ensure logistics for the interview day (travel time, location, etc.).
#    - **Timeline**: Dec 6 (1 day).
#    - **Dependencies**: Completion of Task 6.
#    - **Deliverables**: Checklist of items for the interview.
#
# ### Gantt Chart Visualization
#
# Below is a Gantt Chart reflecting the project timeline for the preparation:
#
# ```
# | Task                           | Nov 19  | Nov 20  | Nov 21  | Nov 22  | Nov 23  | Nov 24  | Nov 25  | Nov 26  | Nov 27  | Nov 28  | Nov 29  | Dec 1   | Dec 2   | Dec 3   | Dec 4   | Dec 5   | Dec 6   |
# |--------------------------------|---------|---------|---------|---------|---------|---------|---------|---------|---------|---------|---------|---------|---------|---------|---------|---------|---------|
# | Research Common Questions       | ███████ | ███████ | ███████ |         |         |         |         |         |         |         |         |         |         |         |         |         |         |
# | Prepare Responses              |         |         |         | ███████ | ███████ | ███████ |         |         |         |         |         |         |         |         |         |         |         |
# | Develop Presentation           |         |         |         |         |         |         |         | ███████ | ███████ | ███████ |         |         |         |         |         |         |         |
# | Rehearse Presentation          |         |         |         |         |         |         |         |         |         |         | ███████ | ███████ | ███████ |         |         |         |         |
# | Mock Interview                 |         |         |         |         |         |         |         |         |         |         |         |         | ███████ |         |         |         |         |
# | Finalize Preparation           |         |         |         |         |         |         |         |         |         |         |         |         |         | ███████ | ███████ | ███████ |         |
# | Day Before Interview Preparation|         |         |         |         |         |         |         |         |         |         |         |         |         |         |         |         | ███████ |
# ```
#
# ### Summary of Key Dates:
# - Nov 19 – Nov 21: Research Questions
# - Nov 22 – Nov 25: Prepare Responses
# - Nov 26 – Nov 28: Develop Presentation
# - Nov 29 – Dec 1: Rehearse Presentation
# - Dec 2: Mock Interview
# - Dec 3 – Dec 5: Finalize Preparation
# - Dec 6: Day Before Interview Preparation
#
# By following this detailed breakdown and adhering to the timelines, you will be thoroughly prepared for your interview as Practice Manager for a GP surgery in the UK. Good luck!
#
#
# # Agent: Expert Estimation Analyst
# ## Task: Thoroughly evaluate each task in the Preperation for Interview as Practice Manager for a GP surgery UK project to estimate the time, resources, and effort required. Use historical data, task complexity, and available resources to provide a realistic estimation for each task.
#
#
#
# # Agent: Expert Estimation Analyst
# ## Final Answer:
# ### Detailed Estimation Report for "Preparation for Interview as Practice Manager for a GP Surgery UK"
#
# This report summarizes the time, resources, and effort estimates required for each task as part of your preparation for the interview. Each task is assessed based on historical data, task complexity, and resource availability. Additionally, a summary of potential risks and uncertainties is included to ensure all aspects are comprehensively covered.
#
# ---
#
# #### Task 1: Research Common Practice Manager Interview Questions
# - **Scope**: Identify and compile key interview questions typically asked for Practice Manager roles in GP surgeries.
# - **Estimated Time**: 3 days
# - **Effort Required**: 10 hours (3.33 hours per day)
# - **Resources Needed**:
#   - 1 Researcher (Yourself)
# - **Deliverables**: List of at least 15 common interview questions.
#
# ---
#
# #### Task 2: Prepare Responses for Interview Questions
# - **Scope**: Craft personalized responses using the STAR technique.
# - **Estimated Time**: 4 days
# - **Effort Required**: 16 hours (4 hours per day)
# - **Resources Needed**:
#   - 1 Writer/Practitioner (Yourself)
# - **Deliverables**: Document containing rehearsed answers to all identified questions.
#
# ---
#
# #### Task 3: Develop Presentation on Innovative Primary Care
# - **Scope**: Create a presentation with ideas on enhancing innovation within primary care.
# - **Estimated Time**: 3 days
# - **Effort Required**: 12 hours (4 hours per day)
# - **Resources Needed**:
#   - 1 Designer (Yourself)
#   - PowerPoint or presentation software
# - **Deliverables**: Completed PowerPoint presentation maximum of 10 slides.
#
# ---
#
# #### Task 4: Rehearse Presentation Delivery
# - **Scope**: Practice the delivery of the presentation multiple times.
# - **Estimated Time**: 3 days
# - **Effort Required**: 9 hours (3 hours per day)
# - **Resources Needed**:
#   - 1 Presenter (Yourself)
#   - Recording device for practice sessions
# - **Deliverables**: Recorded practice sessions for self-review.
#
# ---
#
# #### Task 5: Mock Interview with Feedback
# - **Scope**: Schedule a mock interview session with a mentor.
# - **Estimated Time**: 1 day
# - **Effort Required**: 2 hours (including scheduling and interview time)
# - **Resources Needed**:
#   - 1 Interviewer (Jan du Plessis or another mentor)
#   - 1 Interviewee (Yourself)
# - **Deliverables**: Feedback notes and suggestions for improvement.
#
# ---
#
# #### Task 6: Finalize Interview Preparation
# - **Scope**: Review all materials and make necessary adjustments.
# - **Estimated Time**: 3 days
# - **Effort Required**: 9 hours (3 hours per day)
# - **Resources Needed**:
#   - 1 Reviewer (Yourself)
#   - Printing supplies (if needed)
# - **Deliverables**: Finalized interview documents and presentation materials.
#
# ---
#
# #### Task 7: Day Before Interview Preparation
# - **Scope**: Light review of materials, preparing outfit, and logistical arrangements.
# - **Estimated Time**: 1 day
# - **Effort Required**: 3 hours
# - **Resources Needed**:
#   - 1 Organizer (Yourself)
# - **Deliverables**: Checklist of items for the interview.
#
# ---
#
# ### Summary of Estimated Total Effort
# - **Total Estimated Time**: 17 days (including all tasks)
# - **Total Estimated Effort**: 59 hours
#
# ---
#
# ### Risks and Uncertainties
# 1. **Time Management**: Unexpected interruptions could delay specific tasks. Mitigation includes setting specific hours dedicated solely to preparation.
# 2. **Feedback Reception**: Variations in mentor feedback may lead to more revisions, necessitating additional time.
# 3. **Emotional Readiness**: Anxiety or unanticipated personal issues could impact performance during mock interviews or rehearsals. Scheduling flexibility for additional practice may help.
# 4. **Resource Availability**: Delays in scheduling mock interviews or accessing required software could affect the timeline. Early bookings and preparations can mitigate this risk.
#
# By systematically following this estimation and preparing accordingly, you will be well-positioned for your interview as a Practice Manager for a GP surgery in the UK. Best of luck!
#
#
# # Agent: Resource Allocation Strategist
# ## Task: Strategically allocate tasks for the Preperation for Interview as Practice Manager for a GP surgery UK project to team members based on their skills, availability, and current workload. Ensure that each task is assigned to the most suitable team member and that the workload is evenly distributed.
#
# Team members:
#
# - Jan du Plessis (Practice Manager)
#
#
#
#
# # Agent: Resource Allocation Strategist
# ## Final Answer:
# ### Resource Allocation Chart for the Preparation of Interview as Practice Manager for a GP Surgery UK Project
#
# | Task                                                       | Team Member          | Start Date | End Date   | Estimated Effort (Hours) |
# |-----------------------------------------------------------|----------------------|------------|------------|--------------------------|
# | Research Common Practice Manager Interview Questions       | Jan du Plessis      | Day 1      | Day 3      | 10                       |
# | Prepare Responses for Interview Questions                  | Jan du Plessis      | Day 4      | Day 7      | 16                       |
# | Develop Presentation on Innovative Primary Care            | Jan du Plessis      | Day 8      | Day 10     | 12                       |
# | Rehearse Presentation Delivery                             | Jan du Plessis      | Day 11     | Day 13     | 9                        |
# | Mock Interview with Feedback                               | Jan du Plessis      | Day 14     | Day 14     | 2                        |
# | Finalize Interview Preparation                             | Jan du Plessis      | Day 15     | Day 17     | 9                        |
# | Day Before Interview Preparation                           | Jan du Plessis      | Day 18     | Day 18     | 3                        |
#
# ### Summary of Allocations
#
# 1. **Research Common Practice Manager Interview Questions**
#    - **Rationale**: Jan is experienced and knowledgeable about GP surgery interview processes, making him the most suitable for this research task.
#
# 2. **Prepare Responses for Interview Questions**
#    - **Rationale**: Jan has the ability to articulate personal experiences well, making him the right choice to develop thoughtful and relevant responses using the STAR technique.
#
# 3. **Develop Presentation on Innovative Primary Care**
#    - **Rationale**: With Jan's background in managing primary care, he can effectively articulate innovative ideas and create a compelling presentation.
#
# 4. **Rehearse Presentation Delivery**
#    - **Rationale**: Jan's prior experience in public speaking equips him to rehearse and refine his presentation delivery, ensuring he presents confidently.
#
# 5. **Mock Interview with Feedback**
#    - **Rationale**: Jan du Plessis will act as the interviewer given his familiarity with the interview process, providing valuable feedback after the session.
#
# 6. **Finalize Interview Preparation**
#    - **Rationale**: Jan's organized approach will ensure that all materials are reviewed and refined, preparing everything for the final interview.
#
# 7. **Day Before Interview Preparation**
#    - **Rationale**: As the organizer, Jan can ensure that all preparations are completed, contributing to a solid final review before his interview.
#
# ### Overall Assessment
# The task allocation is designed to leverage Jan du Plessis's skills and availability while preventing any overload on his schedule. Each task builds on Jan's strengths, leading to a thorough and effective preparation process for the interview with risk mitigation strategies in place, ensuring Jan feels confident and well-prepared.

# %% [markdown]
# **Cost** Estimation

# %%
import pandas as pd

costs = 0.150 * (crew.usage_metrics.prompt_tokens + crew.usage_metrics.completion_tokens) / 1_000_000
print(f"Total costs: ${costs:.4f}")

# Convert UsageMetrics instance to a DataFrame
df_usage_metrics = pd.DataFrame([crew.usage_metrics.dict()])
df_usage_metrics
# Out:
# Total costs: $0.0023
#    total_tokens  prompt_tokens  completion_tokens  successful_requests
# 0         15624           9948               5676                    9

# %% [markdown]
# <div class='status' style='background-color: #0f766e; color: white; padding-top: 2px; padding-bottom: 2px; padding-left: 7px; padding-right: 7px; border-radius: 6px; font-family: Arial, sans-serif; font-size: 18px; display: inline-block; text-align: center; box-shadow: 0px 3px 4px rgba(0, 0, 0, 0.2);'>Crewai<b> Final Output</b></div>

# %% [markdown]
# Inspect **Pydantic Output**

# %%
result.pydantic.dict()
# Out:
# {'tasks': [{'task_name': 'Research Common Practice Manager Interview Questions',
#    'estimated_time_hours': 10.0,
#    'required_resources': ['Jan du Plessis']},
#   {'task_name': 'Prepare Responses for Interview Questions',
#    'estimated_time_hours': 16.0,
#    'required_resources': ['Jan du Plessis']},
#   {'task_name': 'Develop Presentation on Innovative Primary Care',
#    'estimated_time_hours': 12.0,
#    'required_resources': ['Jan du Plessis']},
#   {'task_name': 'Rehearse Presentation Delivery',
#    'estimated_time_hours': 9.0,
#    'required_resources': ['Jan du Plessis']},
#   {'task_name': 'Mock Interview with Feedback',
#    'estimated_time_hours': 2.0,
#    'required_resources': ['Jan du Plessis']},
#   {'task_name': 'Finalize Interview Preparation',
#    'estimated_time_hours': 9.0,
#    'required_resources': ['Jan du Plessis']},
#   {'task_name': 'Day Before Interview Preparation',
#    'estimated_time_hours': 3.0,
#    'required_resources': ['Jan du Plessis']}],
#  'milestones': [{'milestone_name': 'Complete Research and Response Preparation',
#    'tasks': ['Research Common Practice Manager Interview Questions',
#     'Prepare Responses for Interview Questions']},
#   {'milestone_name': 'Final Presentation Development and Rehearsal',
#    'tasks': ['Develop Presentation on Innovative Primary Care',
#     'Rehearse Presentation Delivery']},
#   {'milestone_name': 'Conduct Mock Interview',
#    'tasks': ['Mock Interview with Feedback']},
#   {'milestone_name': 'Finalize Preparation',
#    'tasks': ['Finalize Interview Preparation',
#     'Day Before Interview Preparation']}]}

# %%
tasks = result.pydantic.dict()['tasks']
df_tasks = pd.DataFrame(tasks)

# Display the DataFrame as an HTML table
df_tasks.style.set_table_attributes('border="1"').set_caption("Task Details").set_table_styles(
    [{'selector': 'th, td', 'props': [('font-size', '120%')]}]
)
# Out:
# <style type="text/css">
# #T_07bad th {
#   font-size: 120%;
# }
# #T_07bad  td {
#   font-size: 120%;
# }
# </style>
# <table id="T_07bad" border="1">
#   <caption>Task Details</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_07bad_level0_col0" class="col_heading level0 col0" >task_name</th>
#       <th id="T_07bad_level0_col1" class="col_heading level0 col1" >estimated_time_hours</th>
#       <th id="T_07bad_level0_col2" class="col_heading level0 col2" >required_resources</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_07bad_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_07bad_row0_col0" class="data row0 col0" >Research Common Practice Manager Interview Questions</td>
#       <td id="T_07bad_row0_col1" class="data row0 col1" >10.000000</td>
#       <td id="T_07bad_row0_col2" class="data row0 col2" >['Jan du Plessis']</td>
#     </tr>
#     <tr>
#       <th id="T_07bad_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_07bad_row1_col0" class="data row1 col0" >Prepare Responses for Interview Questions</td>
#       <td id="T_07bad_row1_col1" class="data row1 col1" >16.000000</td>
#       <td id="T_07bad_row1_col2" class="data row1 col2" >['Jan du Plessis']</td>
#     </tr>
#     <tr>
#       <th id="T_07bad_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_07bad_row2_col0" class="data row2 col0" >Develop Presentation on Innovative Primary Care</td>
#       <td id="T_07bad_row2_col1" class="data row2 col1" >12.000000</td>
#       <td id="T_07bad_row2_col2" class="data row2 col2" >['Jan du Plessis']</td>
#     </tr>
#     <tr>
#       <th id="T_07bad_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_07bad_row3_col0" class="data row3 col0" >Rehearse Presentation Delivery</td>
#       <td id="T_07bad_row3_col1" class="data row3 col1" >9.000000</td>
#       <td id="T_07bad_row3_col2" class="data row3 col2" >['Jan du Plessis']</td>
#     </tr>
#     <tr>
#       <th id="T_07bad_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_07bad_row4_col0" class="data row4 col0" >Mock Interview with Feedback</td>
#       <td id="T_07bad_row4_col1" class="data row4 col1" >2.000000</td>
#       <td id="T_07bad_row4_col2" class="data row4 col2" >['Jan du Plessis']</td>
#     </tr>
#     <tr>
#       <th id="T_07bad_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_07bad_row5_col0" class="data row5 col0" >Finalize Interview Preparation</td>
#       <td id="T_07bad_row5_col1" class="data row5 col1" >9.000000</td>
#       <td id="T_07bad_row5_col2" class="data row5 col2" >['Jan du Plessis']</td>
#     </tr>
#     <tr>
#       <th id="T_07bad_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_07bad_row6_col0" class="data row6 col0" >Day Before Interview Preparation</td>
#       <td id="T_07bad_row6_col1" class="data row6 col1" >3.000000</td>
#       <td id="T_07bad_row6_col2" class="data row6 col2" >['Jan du Plessis']</td>
#     </tr>
#   </tbody>
# </table>

# %%
milestones = result.pydantic.dict()['milestones']
df_milestones = pd.DataFrame(milestones)

# Display the DataFrame as an HTML table
df_milestones.style.set_table_attributes('border="1"').set_caption("Task Details").set_table_styles(
    [{'selector': 'th, td', 'props': [('font-size', '120%')]}]
)
# Out:
# <style type="text/css">
# #T_c8391 th {
#   font-size: 120%;
# }
# #T_c8391  td {
#   font-size: 120%;
# }
# </style>
# <table id="T_c8391" border="1">
#   <caption>Task Details</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c8391_level0_col0" class="col_heading level0 col0" >milestone_name</th>
#       <th id="T_c8391_level0_col1" class="col_heading level0 col1" >tasks</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c8391_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_c8391_row0_col0" class="data row0 col0" >Complete Research and Response Preparation</td>
#       <td id="T_c8391_row0_col1" class="data row0 col1" >['Research Common Practice Manager Interview Questions', 'Prepare Responses for Interview Questions']</td>
#     </tr>
#     <tr>
#       <th id="T_c8391_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_c8391_row1_col0" class="data row1 col0" >Final Presentation Development and Rehearsal</td>
#       <td id="T_c8391_row1_col1" class="data row1 col1" >['Develop Presentation on Innovative Primary Care', 'Rehearse Presentation Delivery']</td>
#     </tr>
#     <tr>
#       <th id="T_c8391_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_c8391_row2_col0" class="data row2 col0" >Conduct Mock Interview</td>
#       <td id="T_c8391_row2_col1" class="data row2 col1" >['Mock Interview with Feedback']</td>
#     </tr>
#     <tr>
#       <th id="T_c8391_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_c8391_row3_col0" class="data row3 col0" >Finalize Preparation</td>
#       <td id="T_c8391_row3_col1" class="data row3 col1" >['Finalize Interview Preparation', 'Day Before Interview Preparation']</td>
#     </tr>
#   </tbody>
# </table>
